# %%
import pandas as pd
import statsmodels.api as sm
import pylab as pl
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn import preprocessing
from sklearn import svm
import os
from mpl_toolkits.basemap import Basemap

# %matplotlib inline

# %%
TRAIN = pd.read_csv("data/train.csv")

# %%
TRAIN.head(10)
# Out:
#                  Dates        Category                        Descript  \
# 0  2015-05-13 23:53:00        WARRANTS                  WARRANT ARREST
# 1  2015-05-13 23:53:00  OTHER OFFENSES        TRAFFIC VIOLATION ARREST
# 2  2015-05-13 23:33:00  OTHER OFFENSES        TRAFFIC VIOLATION ARREST
# 3  2015-05-13 23:30:00   LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO
# 4  2015-05-13 23:30:00   LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO
# 5  2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM UNLOCKED AUTO
# 6  2015-05-13 23:30:00   VEHICLE THEFT               STOLEN AUTOMOBILE
# 7  2015-05-13 23:30:00   VEHICLE THEFT               STOLEN AUTOMOBILE
# 8  2015-05-13 23:00:00   LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO
# 9  2015-05-13 23:00:00   LARCENY/THEFT    GRAND THEFT FROM LOCKED AUTO
#
#    DayOfWeek PdDistrict      Resolution                        Address  \
# 0  Wednesday   NORTHERN  ARREST, BOOKED             OAK ST / LAGUNA ST
# ...

# %%
print sorted(TRAIN['Category'].unique())
print len(TRAIN['Category'].unique())
print TRAIN.shape
# Out:
# ['ARSON', 'ASSAULT', 'BAD CHECKS', 'BRIBERY', 'BURGLARY', 'DISORDERLY CONDUCT', 'DRIVING UNDER THE INFLUENCE', 'DRUG/NARCOTIC', 'DRUNKENNESS', 'EMBEZZLEMENT', 'EXTORTION', 'FAMILY OFFENSES', 'FORGERY/COUNTERFEITING', 'FRAUD', 'GAMBLING', 'KIDNAPPING', 'LARCENY/THEFT', 'LIQUOR LAWS', 'LOITERING', 'MISSING PERSON', 'NON-CRIMINAL', 'OTHER OFFENSES', 'PORNOGRAPHY/OBSCENE MAT', 'PROSTITUTION', 'RECOVERED VEHICLE', 'ROBBERY', 'RUNAWAY', 'SECONDARY CODES', 'SEX OFFENSES FORCIBLE', 'SEX OFFENSES NON FORCIBLE', 'STOLEN PROPERTY', 'SUICIDE', 'SUSPICIOUS OCC', 'TREA', 'TRESPASS', 'VANDALISM', 'VEHICLE THEFT', 'WARRANTS', 'WEAPON LAWS']
# 39
# (878049, 9)

# %%
# Zoom in on San Francisco
my_map = Basemap(projection='merc', lat_0=37.8787, lon_0=-121.9435,
                  resolution='i', area_thresh=0.05,
                    llcrnrlon=-122.601163, llcrnrlat=37.574554,
                    urcrnrlon=-122.241954, urcrnrlat=37.852897)

fig = plt.figure(figsize=(20,20), dpi=200)

my_map.drawcoastlines()
my_map.drawcountries()
my_map.fillcontinents(color='cyan')
my_map.drawmapboundary()

# Plot lon/lat
lons = TRAIN['X'].values
lats = TRAIN['Y'].values

x,y = my_map(lons, lats)
my_map.plot(x, y, 'bo', markersize=0.5)
 
plt.show()
